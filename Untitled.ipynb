# %%
import pandas as pd
import numpy as np
import psycopg2 as pg

# %%
import os
e2016_path =  "/home/neilor/e2016"
os.chdir(e2016_path+"/tse")
connect_cmd = "dbname='e2016' user='neilor' host='localhost' password='n1f2c3n1'"
from sqlalchemy import create_engine
engine = create_engine('postgresql://neilor:n1f2c3n1@localhost:5432/e2016')
## conda install -c conda-forge ipython-sql 
# %load_ext sql
# %sql postgresql://neilor:n1f2c3n1@/e2016
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: neilor@e2016'

# %%
df_receitas_ac = pd.read_csv('/home/neilor/e2016/tse/prestacao_contas_final_2016/receitas_candidatos_prestacao_contas_final_2016_AC.txt', sep=';', encoding='latin_1', quotechar='"', decimal=',', dtype='str')
df_receitas_ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15278 entries, 0 to 15277
# Data columns (total 35 columns):
# Cód. Eleição                                   15278 non-null object
# Desc. Eleição                                  15278 non-null object
# Data e hora                                    15278 non-null object
# CNPJ Prestador Conta                           15278 non-null object
# Sequencial Candidato                           15278 non-null object
# UF                                             15278 non-null object
# Sigla da UE                                    15278 non-null object
# Nome da UE                                     15278 non-null object
# Sigla  Partido                                 15278 non-null object
# Numero candidato                               15278 non-null object
# Cargo                                          15278 non-null object
# Nome candidato                                 15278 non-null object
# ...

# %%
sqld = """
create table tse.despesas_2016_ac
(
cod_eleicao varchar,
desc_eleicao varchar,
data_e_hora varchar,
cnpj_prestador_conta varchar,
sequencial_candidato varchar,
uf varchar,
sigla_da_ue varchar,
nome_da_ue varchar,
sigla_partido varchar,
numero_candidato varchar,
cargo varchar,
nome_candidato varchar,
cpf_do_candidato varchar,
cpf_do_vice_suplente varchar,
tipo_de_documento varchar,
numero_do_documento varchar,
cpf_cnpj_do_fornecedor varchar,
nome_do_fornecedor varchar,
nome_do_fornecedor_receita_federal varchar,
cod_setor_economico_do_fornecedor varchar,
setor_economico_do_fornecedor varchar,
data_da_despesa varchar,
valor_despesa varchar,
tipo_despesa varchar,
descricao_da_despesa varchar
);"""

# %sql {sqld}
# Out:
# Done.
# []

# %%
sqlr = """
CREATE TABLE tse.receitas_2016_ac
(
  cod_eleicao character varying,
  desc_eleicao character varying,
  data_e_hora character varying,
  cnpj_prestador_conta character varying,
  sequencial_candidato character varying,
  uf character varying,
  sigla_da_ue character varying,
  nome_da_ue character varying,
  sigla__partido character varying,
  numero_candidato character varying,
  cargo character varying,
  nome_candidato character varying,
  cpf_do_candidato character varying,
  cpf_do_vice_suplente character varying,
  numero_recibo_eleitoral character varying,
  numero_do_documento character varying,
  cpf_cnpj_do_doador character varying,
  nome_do_doador character varying,
  nome_do_doador_receita_federal character varying,
  sigla_ue_doador character varying,
  numero_partido_doador character varying,
  numero_candidato_doador character varying,
  cod_setor_economico_do_doador character varying,
  setor_economico_do_doador character varying,
  data_da_receita character varying,
  valor_receita character varying,
  tipo_receita character varying,
  fonte_recurso character varying,
  especie_recurso character varying,
  descricao_da_receita character varying,
  cpf_cnpj_do_doador_originario character varying,
  nome_do_doador_originario character varying,
  tipo_doador_originario character varying,
  setor_economico_do_doador_originario character varying,
  nome_do_doador_originario_receita_federal character varying
)"""
# %sql {sqlr}

# %%
sql = """
-
conn = pg.connect(connect_cmd)
cur = conn.cursor()
cur.execute(sql)
cur.close()
conn.close()

# %%
def copy_table_from(table,file_csv):
    return "COPY "+table+" FROM '"+file_csv+"""'( 
        FORMAT CSV,
        OIDS false,
        FREEZE false,
        DELIMITER ';',
        NULL '',
        HEADER true,
        QUOTE '"',
        ENCODING 'LATIN-1'
        );
    """

for root, dirs, files, rootfd in os.fwalk("/home/neilor/e2016/tse/prestacao_contas_final_2016/", topdown=False):
    for csvfile in files:
        filename = os.path.splitext(os.path.basename(csvfile))[0]
        copy = copy_table_from('tse.receitas_2016_ac',filename)
        print(copy)
        # %sql {copy}
# Out:
# COPY tse.receitas_2016_ac FROM '/home/neilor/e2016/tse/prestacao_contas_final_2016/receitas_candidatos_prestacao_contas_final_2016_SP.txt'(
#         FORMAT CSV,
#         OIDS false,
#         FREEZE false,
#         DELIMITER ';',
#         NULL '',
#         HEADER true,
#         QUOTE '"',
#
#         ENCODING 'LATIN-1'
#         );
#
# 594669 rows affected.
# []

# %%
df_receitas_ac = pd.read_csv('/home/neilor/e2016/tse/consulta_cand_2016/consulta_cand_2016_PR.txt', sep=';', encoding='latin_1', quotechar='"', decimal=',', dtype='str')
df_receitas_ac.info()
df_receitas_ac.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31385 entries, 0 to 31384
# Data columns (total 46 columns):
# 17/10/2017                                     31385 non-null object
# 21:03:42                                       31385 non-null object
# 2016                                           31385 non-null object
# 1                                              31385 non-null object
# Eleições Municipais 2016                       31385 non-null object
# PR                                             31385 non-null object
# 78131                                          31385 non-null object
# RIBEIRÃO CLARO                                 31385 non-null object
# 13                                             31385 non-null object
# VEREADOR                                       31385 non-null object
# ODAIR DO PRADO                                 31385 non-null object
# 160000001687                                   31385 non-null object
# ...
